# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
tips=pd.read_csv("tips.csv")
type(iris_df)
# Out:
# sklearn.utils.Bunch

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time size
# 0       16.99  1.01  Female     No  Sun  Dinner    2
# 1       10.34  1.66    Male     No  Sun  Dinner    3
# 2       21.01  3.50    Male     No  Sun  Dinner    3
# 3       23.68  3.31    Male     No  Sun  Dinner    2
# 4       24.59  3.61  Female     No  Sun  Dinner    4

# %%
fig,ax=plt.subplots()
ax.violinplot(tips["total_bill"], vert=False)
plt.show()

# %%
fig,ax=plt.subplots(0)
tips.plot(x="total_bill",y="tip",kind="scatter")

# %%
tips.plot(x="total_bill",y="tip",width=0.2,kind="bar")

# %%
tips.plot("day","tip",width=0.2,kind="hist")

# %%
tips.plot(y="total_bill",kind="pie")

# %%
tips.plot(y="tip",kind="area")

# %%
tips.plot(x="tip",y="total_bill",kind="kde")

# %%
tips.plot(y="total_bill",x="tip",kind="hexbin",gridsize=20)#alternative of scatter
